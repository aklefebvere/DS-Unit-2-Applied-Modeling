# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 3, Module 3*
#
# ---
#
#
# # Permutation & Boosting
#
# You will use your portfolio project dataset for all assignments this sprint.
#
# ## Assignment
#
# Complete these tasks for your project, and document your work.
#
# - [ ] If you haven't completed assignment #1, please do so first.
# - [ ] Continue to clean and explore your data. Make exploratory visualizations.
# - [ ] Fit a model. Does it beat your baseline?
# - [ ] Try xgboost.
# - [ ] Get your model's permutation importances.
#
# You should try to complete an initial model today, because the rest of the week, we're making model interpretation visualizations.
#
# But, if you aren't ready to try xgboost and permutation importances with your dataset today, that's okay. You can practice with another dataset instead. You may choose any dataset you've worked with previously.
#
# The data subdirectory includes the Titanic dataset for classification and the NYC apartments dataset for regression. You may want to choose one of these datasets, because example solutions will be available for each.
#
#
# ## Reading
#
# Top recommendations in _**bold italic:**_
#
# #### Permutation Importances
# - _**[Kaggle / Dan Becker: Machine Learning Explainability](https://www.kaggle.com/dansbecker/permutation-importance)**_
# - [Christoph Molnar: Interpretable Machine Learning](https://christophm.github.io/interpretable-ml-book/feature-importance.html)
#
# #### (Default) Feature Importances
#   - [Ando Saabas: Selecting good features, Part 3, Random Forests](https://blog.datadive.net/selecting-good-features-part-iii-random-forests/)
#   - [Terence Parr, et al: Beware Default Random Forest Importances](https://explained.ai/rf-importance/index.html)
#
# #### Gradient Boosting
#   - [A Gentle Introduction to the Gradient Boosting Algorithm for Machine Learning](https://machinelearningmastery.com/gentle-introduction-gradient-boosting-algorithm-machine-learning/)
#   - _**[A Kaggle Master Explains Gradient Boosting](http://blog.kaggle.com/2017/01/23/a-kaggle-master-explains-gradient-boosting/)**_
#   - [_An Introduction to Statistical Learning_](http://www-bcf.usc.edu/~gareth/ISL/ISLR%20Seventh%20Printing.pdf) Chapter 8
#   - [Gradient Boosting Explained](http://arogozhnikov.github.io/2016/06/24/gradient_boosting_explained.html)
#   - _**[Boosting](https://www.youtube.com/watch?v=GM3CDQfQ4sw) (2.5 minute video)**_

# %%
# import dataset
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/aklefebvere/DS-Unit-2-Applied-Modeling/master/train-data.csv')

# %%
# Create train, test split
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, train_size=0.80, test_size=0.20, random_state=42)

# %%
# Create new train and val split
train, val = train_test_split(train, train_size=0.80, test_size=0.20, random_state=42)

# %%
# Check shape of splits
train.shape, val.shape, test.shape
# Out:
# ((3852, 14), (963, 14), (1204, 14))

# %%
import math
def wrangle(df):
    # Create copy so it doesn't modify the origninal dataframe
    df = df.copy()
    
    # Filter out CNG, LPG, and Electric Fuel_type rows
    df = df[(df['Fuel_Type'] != 'CNG') & (df['Fuel_Type'] != 'LPG')
            & (df['Fuel_Type'] != 'Electric')]
    
    # Columns to drop
    drop = ['New_Price', 'Unnamed: 0']
    df = df.drop(columns=drop)
    
    # Rename columns
    df = df.rename(columns={'Price': 'Price_Lakh', 'Power': 'Power_bhp'})
    
    # Unit conversions
#     df['Price_INR'] = df['Price_Lakh'] * 100000
#     df['Price_USD'] = df['Price_INR'] * 0.013881
    
    # Zeros --> NaN (For Imputation)
    # Written this way just incase I need to replace more zeros
    zero = ['Seats']
    for i in zero:
        df[zero] = df[zero].replace(0.0,np.NaN)
        
    # Strip characters
    df['Power_bhp'] = df['Power_bhp'].str.strip('null bhp')
    df['Engine'] = df['Engine'].str.strip('CC')
    df['Mileage'] = df['Mileage'].str.strip('kmpl')
    
    # Convert series into numeric values
    df['Power_bhp'] = pd.to_numeric(df['Power_bhp'])
    df['Engine'] = pd.to_numeric(df['Engine'])
    df['Mileage'] = pd.to_numeric(df['Mileage'])
    
    return df

# %%
train = wrangle(train)
test = wrangle(test)
val = wrangle(val)

# %%
# See if 
print(type(train['Engine'].iloc[0]))
print(type(train['Mileage'].iloc[0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
# Check head to see if wrangle function worked correctly
train.head()
# Out:
#                                      Name Location  Year  Kilometers_Driven  \
# 5709           Hyundai Xcent 1.2 Kappa SX    Kochi  2017              15029
# 4413                  Maruti Alto 800 LXI    Kochi  2016              51639
# 3376  Toyota Innova 2.5 Z Diesel 7 Seater   Jaipur  2015             100000
# 5545      Land Rover Range Rover Sport SE    Delhi  2014              47000
# 797      Maruti SX4 S Cross DDiS 200 Zeta   Mumbai  2017              26000
#
#      Fuel_Type Transmission Owner_Type  Mileage  Engine  Power_bhp  Seats  \
# 5709    Petrol       Manual      First    19.10  1197.0       82.0    5.0
# 4413    Petrol       Manual      First    22.74   796.0       47.3    5.0
# 3376    Diesel       Manual     Second    12.99  2494.0      100.6    7.0
# 5545    Diesel    Automatic     Second    12.65  2993.0      255.0    5.0
# 797     Diesel       Manual      First    23.65  1248.0       88.5    5.0
#
#       Price_Lakh
# 5709        6.05
# 4413        3.04
# 3376       12.00
# 5545       64.75
# 797         9.75

# %%
# Identify my target and x and y variables
target = 'Price_Lakh'

X_train = train.drop(columns=target)
X_val = val.drop(columns=target)
X_test = test

y_train = np.log1p(train[target])
y_val = np.log1p(val[target])
y_test = np.log1p(test[target])

# %% [markdown]
# # Using RandomForestRegressor

# %%
# Using RandomForestRegressor to fit my model without any feature engineering
# Accuracy is pretty high right off the bat, need to check for leakage
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(
    ce.OrdinalEncoder(),
    SimpleImputer(strategy='median'),
    RandomForestRegressor(random_state=42, n_jobs=-1)
)

pipeline.fit(X_train, y_train)
print('Validation Accuracy:', pipeline.score(X_val, y_val))
# Out:
# Validation Accuracy: 0.9287420990578699

# %% [markdown]
# # Using XGBoost

# %%
# all possible eval_metric metrics
import sklearn.metrics
sorted(sklearn.metrics.SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'jaccard',
#  'jaccard_macro',
#  'jaccard_micro',
#  'jaccard_samples',
#  'jaccard_weighted',
#  'max_error',
#  'mutual_info_score',
#  'neg_brier_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_gamma_deviance',
#  'neg_mean_poisson_deviance',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'neg_root_mean_squared_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'roc_auc_ovo',
#  'roc_auc_ovo_weighted',
#  'roc_auc_ovr',
#  'roc_auc_ovr_weighted',
#  'v_measure_score']

# %%
# Creating a XGB Regressor model using mae as the evaluation metric
from xgboost import XGBRegressor
encoder = ce.OrdinalEncoder()
imputer = SimpleImputer(strategy='median')

X_train_encoded = encoder.fit_transform(X_train)
X_val_encoded = encoder.transform(X_val)

X_train_imputed = imputer.fit_transform(X_train_encoded)
X_val_imputed = imputer.transform(X_val_encoded)

model = XGBRegressor(
    n_estimators = 1000,
    max_depth = 7,
    learning_rate = 0.5,
    n_jobs=-1
)

eval_set = [(X_train_imputed, y_train),
           (X_val_imputed, y_val)]

model.fit(X_train_imputed, y_train,
         eval_set=eval_set,
         eval_metric='mae',
         early_stopping_rounds=150)
# Out:
# [18:47:35] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost_1572314959925/work/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-mae:0.773916	validation_1-mae:0.776738
# Multiple eval metrics have been passed: 'validation_1-mae' will be used for early stopping.
#
# Will train until validation_1-mae hasn't improved in 150 rounds.
# [1]	validation_0-mae:0.402589	validation_1-mae:0.40698
# [2]	validation_0-mae:0.232976	validation_1-mae:0.246553
# [3]	validation_0-mae:0.158384	validation_1-mae:0.183524
# [4]	validation_0-mae:0.127705	validation_1-mae:0.160148
# [5]	validation_0-mae:0.116204	validation_1-mae:0.155325
# [6]	validation_0-mae:0.107861	validation_1-mae:0.151605
# [7]	validation_0-mae:0.103011	validation_1-mae:0.150789
# [8]	validation_0-mae:0.100352	validation_1-mae:0.149086
# [9]	validation_0-mae:0.097053	validation_1-mae:0.146532
# [10]	validation_0-mae:0.093681	validation_1-mae:0.147878
# [11]	validation_0-mae:0.089997	validation_1-mae:0.147204
# [12]	validation_0-mae:0.087782	validation_1-mae:0.146412
# [13]	validation_0-mae:0.0846	validation_1-mae:0.144455
# [14]	validation_0-mae:0.08232	validation_1-mae:0.143496
# [15]	validation_0-mae:0.079601	validation_1-mae:0.142479
# [16]	validation_0-mae:0.077425	validation_1-mae:0.14194
# [17]	validation_0-mae:0.074559	validation_1-mae:0.141898
# [18]	validation_0-mae:0.071433	validation_1-mae:0.141307
# [19]	validation_0-mae:0.069732	validation_1-mae:0.141361
# [20]	validation_0-mae:0.066948	validation_1-mae:0.140559
# [21]	validation_0-mae:0.065265	validation_1-mae:0.140465
# [22]	validation_0-mae:0.064412	validation_1-mae:0.139801
# [23]	validation_0-mae:0.063322	validation_1-mae:0.139417
# [24]	validation_0-mae:0.061827	validation_1-mae:0.139312
# [25]	validation_0-mae:0.060788	validation_1-mae:0.139449
# [26]	validation_0-mae:0.059681	validation_1-mae:0.139938
# [27]	validation_0-mae:0.059188	validation_1-mae:0.140258
# [28]	validation_0-mae:0.057708	validation_1-mae:0.139662
# [29]	validation_0-mae:0.05594	validation_1-mae:0.139491
# [30]	validation_0-mae:0.054152	validation_1-mae:0.138688
# [31]	validation_0-mae:0.051663	validation_1-mae:0.138713
# [32]	validation_0-mae:0.050197	validation_1-mae:0.13833
# [33]	validation_0-mae:0.048866	validation_1-mae:0.13755
# [34]	validation_0-mae:0.047369	validation_1-mae:0.13713
# [35]	validation_0-mae:0.046464	validation_1-mae:0.136788
# [36]	validation_0-mae:0.045173	validation_1-mae:0.136503
# [37]	validation_0-mae:0.044456	validation_1-mae:0.136669
# [38]	validation_0-mae:0.043181	validation_1-mae:0.136363
# [39]	validation_0-mae:0.042849	validation_1-mae:0.136595
# [40]	validation_0-mae:0.041803	validation_1-mae:0.136305
# [41]	validation_0-mae:0.041418	validation_1-mae:0.136211
# [42]	validation_0-mae:0.040254	validation_1-mae:0.135917
# [43]	validation_0-mae:0.039295	validation_1-mae:0.135844
# [44]	validation_0-mae:0.038653	validation_1-mae:0.135559
# [45]	validation_0-mae:0.038103	validation_1-mae:0.13561
# [46]	validation_0-mae:0.037746	validation_1-mae:0.135546
# [47]	validation_0-mae:0.037427	validation_1-mae:0.135285
# [48]	validation_0-mae:0.036675	validation_1-mae:0.135143
# [49]	validation_0-mae:0.035571	validation_1-mae:0.135316
# [50]	validation_0-mae:0.03534	validation_1-mae:0.135485
# [51]	validation_0-mae:0.034227	validation_1-mae:0.13575
# [52]	validation_0-mae:0.033898	validation_1-mae:0.135675
# [53]	validation_0-mae:0.033273	validation_1-mae:0.135618
# [54]	validation_0-mae:0.032305	validation_1-mae:0.135434
# [55]	validation_0-mae:0.031119	validation_1-mae:0.135306
# [56]	validation_0-mae:0.030482	validation_1-mae:0.135424
# [57]	validation_0-mae:0.030061	validation_1-mae:0.135578
# [58]	validation_0-mae:0.029576	validation_1-mae:0.135681
# [59]	validation_0-mae:0.028988	validation_1-mae:0.135471
# [60]	validation_0-mae:0.028217	validation_1-mae:0.13554
# [61]	validation_0-mae:0.027565	validation_1-mae:0.135711
# [62]	validation_0-mae:0.026998	validation_1-mae:0.135862
# [63]	validation_0-mae:0.026666	validation_1-mae:0.135718
# [64]	validation_0-mae:0.026341	validation_1-mae:0.135656
# [65]	validation_0-mae:0.025816	validation_1-mae:0.135723
# [66]	validation_0-mae:0.025154	validation_1-mae:0.135465
# [67]	validation_0-mae:0.02473	validation_1-mae:0.13576
# [68]	validation_0-mae:0.024368	validation_1-mae:0.135722
# [69]	validation_0-mae:0.024181	validation_1-mae:0.135594
# [70]	validation_0-mae:0.023662	validation_1-mae:0.135575
# [71]	validation_0-mae:0.023085	validation_1-mae:0.135496
# [72]	validation_0-mae:0.02268	validation_1-mae:0.135516
# [73]	validation_0-mae:0.022261	validation_1-mae:0.135364
# [74]	validation_0-mae:0.021932	validation_1-mae:0.135521
# [75]	validation_0-mae:0.02159	validation_1-mae:0.135528
# [76]	validation_0-mae:0.021259	validation_1-mae:0.135461
# [77]	validation_0-mae:0.021073	validation_1-mae:0.135434
# [78]	validation_0-mae:0.02056	validation_1-mae:0.135441
# [79]	validation_0-mae:0.020283	validation_1-mae:0.135459
# [80]	validation_0-mae:0.019861	validation_1-mae:0.135391
# [81]	validation_0-mae:0.019647	validation_1-mae:0.135471
# [82]	validation_0-mae:0.019243	validation_1-mae:0.135449
# [83]	validation_0-mae:0.018908	validation_1-mae:0.135343
# [84]	validation_0-mae:0.018568	validation_1-mae:0.135395
# [85]	validation_0-mae:0.018178	validation_1-mae:0.135241
# [86]	validation_0-mae:0.01794	validation_1-mae:0.135213
# [87]	validation_0-mae:0.017663	validation_1-mae:0.135203
# [88]	validation_0-mae:0.017514	validation_1-mae:0.135275
# [89]	validation_0-mae:0.017006	validation_1-mae:0.135209
# [90]	validation_0-mae:0.016711	validation_1-mae:0.135024
# [91]	validation_0-mae:0.016448	validation_1-mae:0.135044
# [92]	validation_0-mae:0.016189	validation_1-mae:0.134968
# [93]	validation_0-mae:0.01581	validation_1-mae:0.135023
# [94]	validation_0-mae:0.015657	validation_1-mae:0.134973
# [95]	validation_0-mae:0.015383	validation_1-mae:0.134852
# [96]	validation_0-mae:0.015142	validation_1-mae:0.134861
# [97]	validation_0-mae:0.01492	validation_1-mae:0.134861
# [98]	validation_0-mae:0.014837	validation_1-mae:0.134901
# [99]	validation_0-mae:0.014631	validation_1-mae:0.134984
# [100]	validation_0-mae:0.014328	validation_1-mae:0.13488
# [101]	validation_0-mae:0.01413	validation_1-mae:0.134865
# [102]	validation_0-mae:0.01392	validation_1-mae:0.13479
# [103]	validation_0-mae:0.013581	validation_1-mae:0.134803
# [104]	validation_0-mae:0.013237	validation_1-mae:0.134785
# [105]	validation_0-mae:0.013084	validation_1-mae:0.134848
# [106]	validation_0-mae:0.012938	validation_1-mae:0.134907
# [107]	validation_0-mae:0.012721	validation_1-mae:0.134948
# [108]	validation_0-mae:0.012551	validation_1-mae:0.134948
# [109]	validation_0-mae:0.012425	validation_1-mae:0.134927
# [110]	validation_0-mae:0.012315	validation_1-mae:0.134981
# [111]	validation_0-mae:0.012216	validation_1-mae:0.134958
# [112]	validation_0-mae:0.012005	validation_1-mae:0.134984
# [113]	validation_0-mae:0.011711	validation_1-mae:0.134918
# [114]	validation_0-mae:0.01151	validation_1-mae:0.134922
# [115]	validation_0-mae:0.011406	validation_1-mae:0.134988
# [116]	validation_0-mae:0.011234	validation_1-mae:0.134934
# [117]	validation_0-mae:0.011144	validation_1-mae:0.13496
# [118]	validation_0-mae:0.010989	validation_1-mae:0.134963
# [119]	validation_0-mae:0.010809	validation_1-mae:0.134962
# [120]	validation_0-mae:0.010705	validation_1-mae:0.134986
# [121]	validation_0-mae:0.010435	validation_1-mae:0.134985
# [122]	validation_0-mae:0.010348	validation_1-mae:0.135015
# [123]	validation_0-mae:0.010074	validation_1-mae:0.135052
# [124]	validation_0-mae:0.009886	validation_1-mae:0.13505
# [125]	validation_0-mae:0.009798	validation_1-mae:0.135061
# [126]	validation_0-mae:0.009588	validation_1-mae:0.135055
# [127]	validation_0-mae:0.009538	validation_1-mae:0.135021
# [128]	validation_0-mae:0.009448	validation_1-mae:0.13503
# [129]	validation_0-mae:0.009244	validation_1-mae:0.135097
# [130]	validation_0-mae:0.009131	validation_1-mae:0.135126
# [131]	validation_0-mae:0.009054	validation_1-mae:0.135149
# [132]	validation_0-mae:0.008965	validation_1-mae:0.135136
# [133]	validation_0-mae:0.00881	validation_1-mae:0.135132
# [134]	validation_0-mae:0.008679	validation_1-mae:0.135188
# [135]	validation_0-mae:0.008434	validation_1-mae:0.135066
# [136]	validation_0-mae:0.008343	validation_1-mae:0.135048
# [137]	validation_0-mae:0.008272	validation_1-mae:0.135081
# [138]	validation_0-mae:0.008076	validation_1-mae:0.135078
# [139]	validation_0-mae:0.008013	validation_1-mae:0.135068
# [140]	validation_0-mae:0.007804	validation_1-mae:0.135098
# [141]	validation_0-mae:0.007642	validation_1-mae:0.135099
# [142]	validation_0-mae:0.007528	validation_1-mae:0.135124
# [143]	validation_0-mae:0.007369	validation_1-mae:0.135172
# [144]	validation_0-mae:0.007244	validation_1-mae:0.135195
# [145]	validation_0-mae:0.007134	validation_1-mae:0.135199
# [146]	validation_0-mae:0.007027	validation_1-mae:0.135199
# [147]	validation_0-mae:0.006919	validation_1-mae:0.135209
# [148]	validation_0-mae:0.006855	validation_1-mae:0.13517
# [149]	validation_0-mae:0.006784	validation_1-mae:0.135129
# [150]	validation_0-mae:0.006679	validation_1-mae:0.135161
# [151]	validation_0-mae:0.006506	validation_1-mae:0.135183
# [152]	validation_0-mae:0.006401	validation_1-mae:0.135224
# [153]	validation_0-mae:0.006356	validation_1-mae:0.1352
# [154]	validation_0-mae:0.006327	validation_1-mae:0.135199
# [155]	validation_0-mae:0.00627	validation_1-mae:0.135199
# [156]	validation_0-mae:0.006195	validation_1-mae:0.135165
# [157]	validation_0-mae:0.006081	validation_1-mae:0.135162
# [158]	validation_0-mae:0.006011	validation_1-mae:0.135159
# [159]	validation_0-mae:0.00595	validation_1-mae:0.135144
# [160]	validation_0-mae:0.005809	validation_1-mae:0.135184
# [161]	validation_0-mae:0.005726	validation_1-mae:0.135173
# [162]	validation_0-mae:0.005675	validation_1-mae:0.135168
# [163]	validation_0-mae:0.005648	validation_1-mae:0.13516
# [164]	validation_0-mae:0.00553	validation_1-mae:0.135172
# [165]	validation_0-mae:0.005411	validation_1-mae:0.135188
# [166]	validation_0-mae:0.005356	validation_1-mae:0.135215
# [167]	validation_0-mae:0.00531	validation_1-mae:0.135184
# [168]	validation_0-mae:0.005247	validation_1-mae:0.135151
# [169]	validation_0-mae:0.005174	validation_1-mae:0.135152
# [170]	validation_0-mae:0.005095	validation_1-mae:0.135186
# [171]	validation_0-mae:0.005039	validation_1-mae:0.13517
# [172]	validation_0-mae:0.004928	validation_1-mae:0.135185
# [173]	validation_0-mae:0.004848	validation_1-mae:0.135211
# [174]	validation_0-mae:0.004778	validation_1-mae:0.135119
# [175]	validation_0-mae:0.004733	validation_1-mae:0.13514
# [176]	validation_0-mae:0.004642	validation_1-mae:0.135142
# [177]	validation_0-mae:0.004584	validation_1-mae:0.135142
# [178]	validation_0-mae:0.004514	validation_1-mae:0.135154
# [179]	validation_0-mae:0.004409	validation_1-mae:0.135155
# [180]	validation_0-mae:0.004355	validation_1-mae:0.135178
# [181]	validation_0-mae:0.004307	validation_1-mae:0.135157
# [182]	validation_0-mae:0.004271	validation_1-mae:0.135156
# [183]	validation_0-mae:0.004251	validation_1-mae:0.135151
# [184]	validation_0-mae:0.00415	validation_1-mae:0.13517
# [185]	validation_0-mae:0.004127	validation_1-mae:0.135176
# [186]	validation_0-mae:0.0041	validation_1-mae:0.135171
# [187]	validation_0-mae:0.004047	validation_1-mae:0.135171
# [188]	validation_0-mae:0.003977	validation_1-mae:0.135162
# [189]	validation_0-mae:0.003958	validation_1-mae:0.135157
# [190]	validation_0-mae:0.003932	validation_1-mae:0.135156
# [191]	validation_0-mae:0.003897	validation_1-mae:0.135164
# [192]	validation_0-mae:0.003861	validation_1-mae:0.135153
# [193]	validation_0-mae:0.003781	validation_1-mae:0.135156
# [194]	validation_0-mae:0.003689	validation_1-mae:0.135124
# [195]	validation_0-mae:0.003621	validation_1-mae:0.135119
# [196]	validation_0-mae:0.003569	validation_1-mae:0.135115
# [197]	validation_0-mae:0.003485	validation_1-mae:0.135107
# [198]	validation_0-mae:0.003461	validation_1-mae:0.135106
# [199]	validation_0-mae:0.003405	validation_1-mae:0.13512
# [200]	validation_0-mae:0.003355	validation_1-mae:0.1351
# [201]	validation_0-mae:0.003311	validation_1-mae:0.135096
# [202]	validation_0-mae:0.003264	validation_1-mae:0.135095
# [203]	validation_0-mae:0.003222	validation_1-mae:0.135071
# [204]	validation_0-mae:0.003205	validation_1-mae:0.135083
# [205]	validation_0-mae:0.003151	validation_1-mae:0.135078
# [206]	validation_0-mae:0.003099	validation_1-mae:0.135065
# [207]	validation_0-mae:0.003026	validation_1-mae:0.135018
# [208]	validation_0-mae:0.002988	validation_1-mae:0.135026
# [209]	validation_0-mae:0.00295	validation_1-mae:0.135059
# [210]	validation_0-mae:0.002908	validation_1-mae:0.135065
# [211]	validation_0-mae:0.002883	validation_1-mae:0.135065
# [212]	validation_0-mae:0.002838	validation_1-mae:0.135053
# [213]	validation_0-mae:0.002806	validation_1-mae:0.135045
# [214]	validation_0-mae:0.002792	validation_1-mae:0.135045
# [215]	validation_0-mae:0.002753	validation_1-mae:0.135039
# [216]	validation_0-mae:0.002733	validation_1-mae:0.135045
# [217]	validation_0-mae:0.002686	validation_1-mae:0.135054
# [218]	validation_0-mae:0.002669	validation_1-mae:0.135053
# [219]	validation_0-mae:0.00265	validation_1-mae:0.135042
# [220]	validation_0-mae:0.002592	validation_1-mae:0.135031
# [221]	validation_0-mae:0.002567	validation_1-mae:0.135032
# [222]	validation_0-mae:0.002514	validation_1-mae:0.13504
# [223]	validation_0-mae:0.002484	validation_1-mae:0.135045
# [224]	validation_0-mae:0.002452	validation_1-mae:0.135034
# [225]	validation_0-mae:0.002413	validation_1-mae:0.135041
# [226]	validation_0-mae:0.002357	validation_1-mae:0.135036
# [227]	validation_0-mae:0.002319	validation_1-mae:0.135043
# [228]	validation_0-mae:0.002282	validation_1-mae:0.135055
# [229]	validation_0-mae:0.002271	validation_1-mae:0.135059
# [230]	validation_0-mae:0.002245	validation_1-mae:0.135067
# [231]	validation_0-mae:0.002224	validation_1-mae:0.135048
# [232]	validation_0-mae:0.002193	validation_1-mae:0.135057
# [233]	validation_0-mae:0.002141	validation_1-mae:0.135055
# [234]	validation_0-mae:0.002119	validation_1-mae:0.135061
# [235]	validation_0-mae:0.002093	validation_1-mae:0.135023
# [236]	validation_0-mae:0.002069	validation_1-mae:0.135027
# [237]	validation_0-mae:0.002031	validation_1-mae:0.135022
# [238]	validation_0-mae:0.002002	validation_1-mae:0.13504
# [239]	validation_0-mae:0.001976	validation_1-mae:0.13503
# [240]	validation_0-mae:0.001937	validation_1-mae:0.135039
# [241]	validation_0-mae:0.001918	validation_1-mae:0.135036
# [242]	validation_0-mae:0.001905	validation_1-mae:0.135045
# [243]	validation_0-mae:0.001873	validation_1-mae:0.135043
# [244]	validation_0-mae:0.001852	validation_1-mae:0.135032
# [245]	validation_0-mae:0.001824	validation_1-mae:0.135031
# [246]	validation_0-mae:0.001807	validation_1-mae:0.135034
# [247]	validation_0-mae:0.001787	validation_1-mae:0.135012
# [248]	validation_0-mae:0.001768	validation_1-mae:0.135021
# [249]	validation_0-mae:0.001745	validation_1-mae:0.135017
# [250]	validation_0-mae:0.001726	validation_1-mae:0.135009
# [251]	validation_0-mae:0.001701	validation_1-mae:0.135017
# [252]	validation_0-mae:0.001674	validation_1-mae:0.135016
# [253]	validation_0-mae:0.001661	validation_1-mae:0.135013
# [254]	validation_0-mae:0.00165	validation_1-mae:0.135014
# Stopping. Best iteration:
# [104]	validation_0-mae:0.013237	validation_1-mae:0.134785
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.5, max_delta_step=0,
#              max_depth=7, min_child_weight=1, missing=None, n_estimators=1000,
#              n_jobs=-1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
# Using the XGB model to find the permutation importance in r^2
from eli5.sklearn import PermutationImportance

model = RandomForestRegressor(random_state=42, n_jobs=-1)
model.fit(X_train_imputed, y_train)

permuter = PermutationImportance(
    model,
    scoring='r2',
    n_iter=5,
    random_state=42
)

permuter.fit(X_val_imputed, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=RandomForestRegressor(bootstrap=True,
#                                                       ccp_alpha=0.0,
#                                                       criterion='mse',
#                                                       max_depth=None,
#                                                       max_features='auto',
#                                                       max_leaf_nodes=None,
#                                                       max_samples=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
#                                                       min_samples_split=2,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       n_estimators=100,
#                                                       n_jobs=-1,
#                                                       oob_score=False,
#                                                       random_state=42,
#                                                       verbose=0,
#                                                       warm_start=False),
#                       n_iter=5, random_state=42, refit=True, scoring='r2')

# %%
# Permutation Importance in r^2
feature_names = X_val.columns.tolist()
pd.Series(permuter.feature_importances_, feature_names).sort_values(ascending=False)
# Out:
# Power_bhp            0.922803
# Year                 0.394076
# Engine               0.086143
# Transmission         0.019209
# Mileage              0.015459
# Kilometers_Driven    0.011234
# Location             0.009466
# Seats                0.007727
# Name                 0.005703
# Fuel_Type            0.003922
# Owner_Type           0.000036
# dtype: float64
